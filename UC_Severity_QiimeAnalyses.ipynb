# %% [markdown]
# # UC Severity Qiime Analyses

# %% [markdown]
# By RM
#
# Environment:Qiime2(2018.4) & Qiime1
#
# Project Abstract:
#
# Ulcerative colitis (UC) is a chronic autoimmune condition defined by intestinal inflammation and concurrent microbiome dysbiosis. Here, we advance the understanding of host-microbiome interactions governing UC by collecting six meta–omic datasets profiling host and microbial molecules in 40 patients displaying a wide range of clinically assessed disease activity (remission to severe). The six datasets provided unique evidence toward a central hypothesis of proteolysis co-occurring with increased disease activity. Metaproteomics identified Bacteroides proteases as a distinguishing feature of severity. Shotgun metagenomics guided taxonomic inferences and revealed that the Bacteroides association was driven primarily by changes in protein and not DNA abundances. Potential evidence of a host response to Bacteroides serine proteases was found in the increase of serum and fecal serine protease inhibitors. Metapeptidomics added evidence of protease activity as an increase of peptide fragments was present among the patients with high severity. In addition, we compare prediction of severity and clinical parameters between data types. In total, our meta-omic platform has provided compelling integrated evidence for host-microbiome interactions during UC and opens the door for protease inhibition as a therapeutic approach for severe UC patients.

# %%
# Initializes the notebook with inline display
# %matplotlib inline

from os import mkdir
import os
import copy
from os.path import abspath, join as pjoin, exists
from shutil import copy2, move
from time import strftime, strptime
from numpy import nan, isnan, arange
from pandas import read_csv, Series, DataFrame
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# 16S.biom
# 16S_biom.qza
# 16S_biom.qzv
# 16S_pmayo_PCoA_Unweighted_CalprotectinSize.png
# 16S_pmayo_PCoA_Unweighted_CalprotectinSize.svg
# 1Search_only/
# 1search_biom.qza
# 1search_biom.qzv
# 1search_common_biom.qza
# 2Search/
# 2search_biom.qza
# 2search_biom.qzv
# 2search_common_biom.qza
# 2searchpDB_pmayo_PCoA_braycurtis_CalprotectinSize.png
# 2searchpDB_pmayo_PCoA_braycurtis_CalprotectinSize.svg
# Bacteroides_Proteases_by_Species_workup.xlsx
# Bacteroides_of_interest.xlsx
# Bacteroides_workup.xlsx
# COG_Spearman_Corrs_Stats_pergene.csv
# Descriptive_Statistics.xlsx
# IGCNormalizedCommonReps.biom
# IGCNormalizedDataAll.biom
# IGC_biom.qza
# IGC_biom.qzv
# IGC_common_biom.qza
# List_of_proteins_NotInSearch1.xlsx
# LowMayoStoolFreq_BH.csv
# Low_severity_remission.csv
# Low_severity_remission_volcanos.ai
# Low_severity_remission_volcanos.png
# Lysozyme_correlations_ordered_MP_corrnonan.csv
# Lysozyme_correlations_ordered_MP_corrwnan.csv
# MG_Bacteroides_Composition.csv
# MG_Enzymes.csv
# MGw0s_LR05_pmayo_Bacteroides.csv
# MPwmin_LR05_pmayo_Bacteroides.csv
# Mayo0Compare.csv
# Mayo0Compare_BH.csv
# Mayo0RemissionCompare.csv
# Mayo0RemissionCompare_BH.csv
# Mayo0_Remission_Volcano.pdf
# Mayo0_Remission_Volcano_TonB.pdf
# Mayo0_Remission_Volcano_TonB.png
# Mayo0_Remission_Volcano_TonB_pi1.pdf
# Mayo0_Remission_Volcano_TonB_pi1.png
# Mayo0_Remission_Volcano_TonB_pi1_BH15.pdf
# Mayo0_Remission_Volcano_expanded.pdf
# Mayo0_Volcano_TonB_pi1.pdf
# Metabolomics.biom
# Metabolomics_biom.qza
# Metabolomics_biom.qzv
# Partial_Mayo_correlations_ordered_MG.csv
# Partial_Mayo_correlations_ordered_MP.csv
# Partial_Mayo_correlations_ordered_MP_corrwnan.csv
# Partial_Mayo_correlations_ordered_nohuman.csv
# Qiime/
# Salmon_CPMs.biom
# Salmon_CPMs_biom.qza
# Serum_Common.biom
# Serum_Common_biom.qza
# Serum_Common_biom.qzv
# Significant_Enzymes_Membranes_Genera.pzfx
# UC_MG_LR05_pmayo_KEGG_ratios.csv
# UC_MG_LR05_pmayo_KEGG_ratios_0s.csv
# UC_MG_LR05_pmayo_KEGG_ratios_nans.csv
# UC_MG_LR05_pmayo_eggNOG_ratios.csv
# UC_MG_LR05_pmayo_eggNOG_ratios_nans.csv
# UC_MP_LR05_Lysozyme_KEGG_ratios_nans.csv
# UC_MP_LR05_pmayo_KEGG_ratios.csv
# UC_MP_LR05_pmayo_KEGG_ratios_nans.csv
# UC_MP_LR05_pmayo_eggNOG_ratios.csv
# UC_MP_LR05_pmayo_eggNOG_ratios_nans.csv
# UC_MP_LR05wmin_pmayo_KEGG_ratios_Bacteroides.csv
# UC_MP_LR05wmin_pmayo_KEGG_ratios_Bacteroides_nostrsplit.csv
# UC_MP_LR05wmin_pmayo_KEGG_ratios_Faecalibacterium.csv
# UC_MP_LR05wmin_pmayo_KEGG_ratios_Faecalibacterium_nostrsplit.csv
# UC_MP_LR05wmin_pmayo_eggNOG_ratios.csv
# UC_MP_LR05wmin_pmayo_eggNOG_ratios_Bacteroides.csv
# UC_MP_LR05wmin_pmayo_eggNOG_ratios_Faecalibacterium.csv
# UC_Severity_Qiime2_Qiime1.ipynb*
# UC_Severity_pDB_Qiime2_pseudo1.ipynb*
# core-metrics-results_2search/
# core-metrics-results_Metabolomics/
# core-metrics-results_pDB_noHuman/
# fdr_tsbh.csv
# pDB1_fwdnrvrse_hits.csv
# pDB1_fwdnrvrse_hits.txt
# pDB_Common_nohuman_biom.qza
# pDB_Common_nohuman_biom.qzv
# pDB_Enzymes.csv
# pDB_MP_annotated(nodups).csv
# pDB_MP_annotated.csv
# pMayo2RemissionCompare.csv
# pMayo2_Remission_Volcano.pdf
# pmayo05_MG0MPwmin_KEGG_ratios_(wPseudo)_Workup.xlsx
# pmayo05_MG0sMPwmin_Genus_ratios_(wPseudo)_Workup.xlsx
# pmayo05_MG_Genus_ratios(noPseudo).csv
# pmayo05_MG_Genus_ratios(wPseudo).csv
# pmayo05_MG_Genus_ratios(wPseudo)_workup.csv
# pmayo05_MG_KEGG_ratios(noPseudo).csv
# pmayo05_MG_KEGG_ratios(wPseudo).csv
# pmayo05_MG_eggNOG_ratios_0s(wPseudo).csv
# pmayo05_MP_Genus_ratios(noPseudo).csv
# pmayo05_MP_Genus_ratios(wPseudo).csv
# pmayo05_MPwmin_Genus_ratios(noPseudo).csv
# pmayo05_MPwmin_Genus_ratios_(wPseudo).csv
# pmayo05_MPwmin_KEGG_ratios(noPseudo).csv
# pmayo05_MPwmin_KEGG_ratios_(wPseudo).csv
# pmayo05_MPwmin_eggNOG_ratios_(wPseudo).csv
# pmayo05_pDB_Bacteroides_ratios(noPseudo).csv
# pmayo05_pDB_Bacteroides_ratios(wPseudo).csv
# pmayo_correlations_MG_corrw0s_10ormoresamples.csv
# pmayo_correlations_ordered_MG_corrw0s.csv
# pmayo_correlations_ordered_MG_corrwnan.csv
# pmayo_correlations_ordered_MG_corrwnan10.csv
# pmayo_correlations_ordered_MP_corrwmins.csv
# pmayo_correlations_ordered_MP_corrwnan.csv
# pmayo_correlations_ordered_MP_corrwnan10.csv
# pmayo_correlations_ordered_MP_corrwnan2.csv
# vmf-map/

# %% [markdown]
# ### Make subset of no-human metaproteomics

# %%
df = pd.read_csv("./2Search/CSVs/NormalizedCommonReps.txt", 
                 sep = '\t', index_col= "datarest$ProteinID")

# %%
#Remove any human derived proteins
df = df[df.index.str.contains('k99_') != False]
df
# Out:
#                            H16          H3          L4         L11  \
# datarest$ProteinID
# k99_1000928_1       111.069493   94.231149  166.363367   99.088192
# k99_1001938_3        46.630938  320.607204  264.045104   74.501569
# k99_1001990_2        57.391732   47.461439  123.003403   32.235909
# k99_1002150_3        30.935689  125.472858  347.763489  148.560410
# k99_1002370_6        46.583836  164.440568  166.747069  134.089458
# k99_1002967_3        27.341552  120.232326  349.095667  193.395062
# k99_1003965_10       24.376980  172.249152  150.505049   18.110006
# k99_1004041_1        53.284447    0.306497    4.638289   61.191568
# k99_1004623_1       119.368003   33.717070   12.766574   38.006418
# k99_1005212_10       54.244065  267.630639   62.279420  124.831251
# k99_1005337_1       154.392649   83.607374  272.072922   63.092778
# k99_1005475_1        41.334795   52.794187  132.989227   34.285508
# k99_1005733_1       131.967098   23.004395  116.745592   46.300057
# k99_1006916_3       175.810806    0.139214    5.430354   25.455806
# k99_1006998_1       217.632768   32.915850  277.607949   32.080584
# k99_1007311_1       172.994521  119.471056    5.150463   20.349668
# k99_1007631_1        36.864080  117.667665  216.172100  126.561557
# k99_1007659_2       323.951407    2.216117   11.720689   30.269739
# k99_100772_1        221.756668  507.788938    5.102968  103.101741
# k99_1007949_1        62.968256   58.710044  281.423659   22.513453
# k99_1008105_1        97.160518   53.102530   46.897418  140.513848
# k99_1008105_2        72.357921   20.590128   19.745163   43.018586
# k99_1008105_3       233.355649   74.324369   15.008242   27.759816
# k99_1008180_1        15.187049  113.536625   13.021212   61.337747
# k99_1008218_1        56.584412  138.779130  242.561476   15.886922
# k99_1008435_3        36.968736  173.767161   95.189930  127.752392
# k99_1008548_2       114.743947   44.819853   65.549676   24.236662
# k99_1008597_2       336.860031   10.450378   12.066680   51.704662
# k99_1008705_2        83.383882   53.365558   47.799088   58.974744
# k99_1008991_1        14.183006   21.144467   16.343396   54.560932
# ...                        ...         ...         ...         ...
# k99_986881_2         71.725067   46.142810  249.027866   20.509308
# k99_988185_3        284.722747  109.255008   21.199096  113.321378
# k99_989559_1         53.745577  285.744149  109.222848   30.145157
# k99_989607_1         21.372486    5.238690    4.239787    7.797743
# k99_989714_5         18.102763   33.725137   78.541373   64.782197
# k99_989874_5        436.717957    7.261263   35.282143   97.395999
# k99_990427_1         88.757610   70.961000  151.333799   36.360445
# k99_990682_2          3.124727   76.672831  102.157108   59.000290
# k99_991061_1         36.536070   25.212403  200.306933   25.807963
# k99_991419_1          3.012734    0.592461    2.226710   23.017513
# k99_991741_1         36.078577    6.200558   11.098007   16.391302
# k99_991826_1          8.093804   52.305888  117.718034   58.529716
# k99_991826_3         19.348388   15.955913   54.466123   38.363492
# k99_99188_2          40.975287   35.414517   17.301511   92.112643
# k99_992336_2         69.489179  110.334996   47.178478    0.706841
# k99_992839_2         41.191678  236.993691  582.003353   26.288025
# k99_99300_10         57.533476   51.688237   70.426056  218.373047
# k99_993197_4          7.388702   18.812668    3.064288   11.812190
# k99_993759_8         72.136854   45.623568   39.880100   42.682101
# k99_9941_1          421.955852   70.549217   30.678601  118.981610
# k99_99441_1          41.289352   93.724856   64.446688  300.902263
# k99_99524_2         778.730579   11.520877   19.098173   40.797132
# k99_995394_1         88.744787    6.591762  184.875953   81.745859
# k99_995896_4        141.243431  107.025153  141.962239   20.507947
# k99_996093_4         41.399251   64.807983   61.345281   80.127394
# k99_996122_1          3.959178    1.678095    1.323174    7.498730
# k99_997245_1          8.710427    5.835441    8.072043   13.406415
# k99_997813_2         19.900002  115.456455  102.160439   73.110311
# k99_997813_3         10.997851  158.856644   90.649466   21.047259
# k99_99970_1          47.707257  100.118122  120.992256   28.672035
#
#                              H8          L3         H11         H20  \
# datarest$ProteinID
# k99_1000928_1         54.591755  173.691705   50.662214  134.574253
# k99_1001938_3         33.129914  149.089471  239.364036   60.129463
# k99_1001990_2         66.112950   69.628543  106.518997  705.535557
# k99_1002150_3         39.245119   43.271356  129.515300   79.409804
# k99_1002370_6         14.935078   52.832114   52.968206  178.658634
# k99_1002967_3         48.804329   53.359054   47.009773  152.000113
# k99_1003965_10       132.123840   28.703120    8.149837  115.727792
# k99_1004041_1        203.231975   88.284329    3.046813    5.299889
# k99_1004623_1        117.899451  185.485691  446.934636   11.686298
# k99_1005212_10        56.083609   54.110338   70.235402  175.656809
# k99_1005337_1         32.272982   24.834490   86.632449  394.377900
# k99_1005475_1         54.319255   87.355216   26.796499  131.341136
# k99_1005733_1         69.666192   45.045068   55.899728    2.445917
# k99_1006916_3         46.773192  102.757996   19.256817    3.847794
# k99_1006998_1        108.743595   71.300360   38.116813  100.084247
# k99_1007311_1         69.172643    3.112321   29.750006    7.817663
# k99_1007631_1         29.536866  148.119197  106.115331  173.137766
# k99_1007659_2          3.051028  530.322777   41.138164   10.867847
# k99_100772_1         195.245184   24.812102   62.937204    5.882766
# k99_1007949_1         51.175672  125.605334   37.996999  264.320399
# k99_1008105_1         35.394027  120.324332  244.362456  602.312953
# k99_1008105_2         39.804201   79.228430   94.875345  747.386813
# k99_1008105_3         68.564973   74.368965   43.459606  353.385122
# k99_1008180_1        102.489074   26.471033  223.678836   39.319820
# k99_1008218_1         69.635360    9.417897   55.037163   54.076108
# k99_1008435_3         24.688385  187.116384   40.011542  101.439969
# k99_1008548_2        103.924199  105.443975   25.129432   34.657164
# k99_1008597_2         66.516863  121.469664  109.961704   83.462251
# k99_1008705_2         92.913103   61.585567  161.752034   24.575543
# k99_1008991_1         27.145712  248.087044   20.066131   10.252830
# ...                         ...         ...         ...         ...
# k99_986881_2          63.446196   63.527754   24.583542   96.667323
# k99_988185_3         118.419744   80.363294   42.946036  464.331237
# k99_989559_1          59.419067  101.868692   91.933955  199.032317
# k99_989607_1          17.208427   84.646844   10.535081   57.181267
# k99_989714_5          25.561647  143.368810   28.542558   24.711359
# k99_989874_5          39.009174  248.418095   40.658572   23.025467
# k99_990427_1         140.097476    6.625953   45.700091   58.809509
# k99_990682_2          30.144200   82.896231   10.458825   13.273222
# k99_991061_1          47.756136   57.971996  269.991030  129.861009
# k99_991419_1           3.387003    1.712442   22.779307    1.775004
# k99_991741_1           6.033534    6.282880   29.432023    1.379454
# k99_991826_1          47.984053   85.682910   12.752715   13.151539
# k99_991826_3          23.794290   51.280761   54.685985   13.570566
# k99_99188_2          411.046092   59.960873   84.538943  114.003832
# k99_992336_2          53.415820  110.156962  181.152375   82.686340
# k99_992839_2          83.354495  582.233477   87.958774   83.684066
# k99_99300_10        1001.555339   63.822298   52.255680   60.389625
# k99_993197_4          16.704778   44.678333   30.332263    1.236302
# k99_993759_8          40.751973   19.616386   98.518508  344.930759
# k99_9941_1            70.286791   69.750482  145.949478  244.268993
# k99_99441_1         1564.878900   11.398853  119.783493   34.885255
# k99_99524_2          407.020702    2.038803   72.388909   11.173429
# k99_995394_1          46.235319  103.827076   67.934138   29.360562
# k99_995896_4         112.438742   13.333790  141.704716   42.099626
# k99_996093_4         117.044491   39.800827  202.847106  176.754750
# k99_996122_1          21.946004    3.967258   43.177695  238.240213
# k99_997245_1          62.608661    6.913223   21.131240  334.887067
# k99_997813_2          55.923188   38.617480   38.744904  138.694299
# k99_997813_3         109.146743   19.985383   18.103251   52.708553
# k99_99970_1          123.491480   45.090449   21.387333   97.332658
#
#                            L10          L7     ...             L16  \
# datarest$ProteinID                             ...
# k99_1000928_1        26.011840   59.754656     ...       68.093307
# k99_1001938_3         6.352032   16.593794     ...       88.449492
# k99_1001990_2       116.762120  146.875607     ...       17.494716
# k99_1002150_3        25.220030   71.962896     ...       62.935518
# k99_1002370_6        62.721379   55.951204     ...      162.402114
# k99_1002967_3        58.934078   43.200448     ...       87.707173
# k99_1003965_10       21.424122   16.858031     ...       57.223006
# k99_1004041_1       195.578089    6.252366     ...      130.641019
# k99_1004623_1       182.239036   24.190626     ...       33.647304
# k99_1005212_10       51.662677   47.703592     ...       95.664787
# k99_1005337_1        16.996699   14.575021     ...      143.982645
# k99_1005475_1        50.314613  108.054515     ...       83.264222
# k99_1005733_1        17.834656   61.272581     ...       97.824029
# k99_1006916_3       144.468301  113.894306     ...      177.030833
# k99_1006998_1        75.199448   98.662185     ...      112.682155
# k99_1007311_1        87.060368  219.169475     ...       83.179488
# k99_1007631_1        10.344472   68.278372     ...       26.826830
# k99_1007659_2        38.951188   18.246542     ...      187.940755
# k99_100772_1        161.211253   73.688159     ...       95.280290
# k99_1007949_1        33.884970  116.922834     ...       79.150747
# k99_1008105_1        68.507910   10.580655     ...       48.559364
# k99_1008105_2        60.187154    7.833829     ...       43.691513
# k99_1008105_3        33.754965    7.039364     ...       31.286745
# k99_1008180_1        47.393270   94.291313     ...       73.628504
# k99_1008218_1        31.608293   22.455110     ...      121.542235
# k99_1008435_3        23.529278   19.802737     ...       37.230945
# k99_1008548_2        96.906225   24.770467     ...       42.855305
# k99_1008597_2         3.592345   89.744451     ...      262.603783
# k99_1008705_2        97.624925  114.127828     ...       85.751608
# k99_1008991_1       239.079743  482.507133     ...        4.575419
# ...                        ...         ...     ...             ...
# k99_986881_2         52.329958   64.337782     ...       64.452276
# k99_988185_3         49.561183    6.171331     ...       23.416377
# k99_989559_1        124.424764   75.420037     ...      191.374727
# k99_989607_1          4.448012   40.092313     ...        6.967357
# k99_989714_5        171.413633  280.820581     ...       41.318265
# k99_989874_5        191.905049    6.042956     ...       79.741161
# k99_990427_1         40.696426    7.899579     ...      110.116921
# k99_990682_2        125.100109    0.376024     ...       83.164092
# k99_991061_1         41.787830   72.995633     ...       63.342419
# k99_991419_1        333.171941  182.074637     ...       13.904292
# k99_991741_1         12.175121  756.155606     ...       24.618277
# k99_991826_1         75.009943   27.793513     ...       48.497533
# k99_991826_3        169.254131  187.965419     ...       45.318710
# k99_99188_2          25.825147   69.377144     ...       60.121992
# k99_992336_2         52.833980  116.850245     ...       81.585943
# k99_992839_2         71.018943   18.976264     ...      146.727643
# k99_99300_10        109.716554  145.773820     ...      102.388925
# k99_993197_4         30.071025   91.500718     ...       53.954294
# k99_993759_8         85.579857   39.813719     ...        4.379129
# k99_9941_1           21.943717   14.361836     ...       20.626701
# k99_99441_1           3.385661    3.022282     ...        1.648258
# k99_99524_2          15.710797    6.437326     ...        3.160433
# k99_995394_1         82.055675  132.537694     ...      141.450007
# k99_995896_4         71.641031   76.769254     ...       62.294905
# k99_996093_4        269.179049   59.190718     ...       52.599381
# k99_996122_1          1.691548    2.118184     ...        2.291872
# k99_997245_1         10.083635    9.986821     ...       13.184112
# k99_997813_2         80.817025   20.941561     ...      142.779126
# k99_997813_3         39.793678   31.804228     ...       93.152357
# k99_99970_1          84.433542   62.712090     ...       66.542855
#
#                             H14           H1          L1          H6  \
# datarest$ProteinID
# k99_1000928_1         71.056933    33.271179  161.770360   70.540445
# k99_1001938_3        410.993816    15.131730   19.084435    3.638069
# k99_1001990_2         12.224755    34.637102   12.661787  126.771758
# k99_1002150_3         21.794327    36.540982   79.051493   42.634040
# k99_1002370_6          1.037451   144.370090  208.113864   14.262005
# k99_1002967_3          9.256106    59.617181  247.086797   24.663200
# k99_1003965_10        41.482728   204.751568   35.337095   53.272303
# k99_1004041_1          9.193953     4.496304  142.587605    0.826234
# k99_1004623_1        118.834157    46.292226   35.476515   33.872342
# k99_1005212_10         7.083284   126.750742  115.386956   37.891127
# k99_1005337_1          1.291334    13.995447   84.466980   17.595855
# k99_1005475_1         81.462515    42.030277  165.868790   53.777821
# k99_1005733_1         10.591840   104.433287  103.352557   69.095019
# k99_1006916_3         10.818418    53.110737  106.636277  106.527928
# k99_1006998_1        341.052887    62.696106   14.234573   65.602727
# k99_1007311_1        287.281548    66.359367  156.395535   43.959460
# k99_1007631_1         61.329672    65.778732   24.884930    7.335209
# k99_1007659_2         22.869324    14.214832  134.948844  327.872525
# k99_100772_1          34.031023   139.726011   58.911694   72.156834
# k99_1007949_1          2.793514    50.310957  222.896789   85.199731
# k99_1008105_1         58.858740    57.157386   11.490327   42.118520
# k99_1008105_2         51.254832    64.158146   20.654935   42.772805
# k99_1008105_3         33.925599    39.628948   22.844824   41.541536
# k99_1008180_1        291.178040    50.062576   27.931189   56.354810
# k99_1008218_1         16.536745    22.638705  138.888164   64.707997
# k99_1008435_3        264.905214    40.525079  116.844388   37.470565
# k99_1008548_2        150.394764    63.493967  184.482410   42.900626
# k99_1008597_2          0.864858   175.382372   25.034425   71.264266
# k99_1008705_2        132.415589    66.312452  120.764616   95.294835
# k99_1008991_1          2.029517    24.949074   22.483890  275.678256
# ...                         ...          ...         ...         ...
# k99_986881_2         158.935581    65.364268  152.094888   47.966426
# k99_988185_3          54.173183    37.626349  106.743917   38.127006
# k99_989559_1          27.189949    52.427279   87.246854   48.851018
# k99_989607_1        1243.113262    22.678447  541.383898   38.994140
# k99_989714_5         173.799895    46.810370  229.354717  138.120506
# k99_989874_5          19.548117    89.645424   18.464332  431.256857
# k99_990427_1          10.819953    34.073402   13.432432   47.333795
# k99_990682_2         111.125592    30.983864   24.564292  159.006282
# k99_991061_1          94.161809    51.982227  326.181419   37.302418
# k99_991419_1           6.770838    19.667648  113.029613  102.713870
# k99_991741_1          24.585423    78.446327  161.702029   28.955127
# k99_991826_1         178.090202    58.703498   17.100617   44.996199
# k99_991826_3         190.781121   140.921684  580.472026   15.913658
# k99_99188_2          241.589395    43.355378  112.401977   43.606543
# k99_992336_2           0.860196    68.124300   15.599012   49.605158
# k99_992839_2          66.717530    56.427479   28.374838  344.149848
# k99_99300_10         284.636193    31.342840  146.327508   34.910865
# k99_993197_4          13.450632    14.947777    8.502076   32.254392
# k99_993759_8           4.373121   149.948053   53.937557  208.164519
# k99_9941_1            62.686112    34.038831   64.669907   73.436938
# k99_99441_1            1.586085  1338.174649    6.760904   28.920598
# k99_99524_2            5.150197    24.043758  120.281227   34.992531
# k99_995394_1         199.246303    74.208047  102.196755  104.131953
# k99_995896_4         174.828352   145.722862   35.921944   44.932540
# k99_996093_4          70.205312    80.329963   51.559799  124.787689
# k99_996122_1           3.622075   567.383281    1.372061   85.329175
# k99_997245_1         320.948201    18.947015    3.636536   92.492587
# k99_997813_2           2.436368    92.180732   45.741706   27.204698
# k99_997813_3          29.941569   207.961046   63.109370   42.633071
# k99_99970_1          297.587182    85.905713   92.736934   27.742234
#
#                            L14          H2          H10         L17  \
# datarest$ProteinID
# k99_1000928_1       101.274311  149.492346    99.904085   58.012858
# k99_1001938_3         2.979719  106.715396    22.169808   66.089185
# k99_1001990_2       104.163969   37.907910   168.860490   30.236346
# k99_1002150_3        61.234510   69.066572   725.394872  136.957015
# k99_1002370_6        43.673788   74.932959    38.915743   45.162795
# k99_1002967_3        51.850043    4.419552    27.218740   21.916938
# k99_1003965_10      127.598116   74.795004    93.190566   92.367805
# k99_1004041_1       266.520335    8.812933    52.492953   17.674539
# k99_1004623_1        52.061963   36.413021   111.688583   22.764500
# k99_1005212_10       82.778597   97.051830   151.377216  138.447806
# k99_1005337_1        26.110809   72.402559    19.235825   45.623446
# k99_1005475_1        67.575000  134.316490    44.658326   73.540616
# k99_1005733_1        48.348803  475.281984    13.203118  111.412930
# k99_1006916_3        50.580339  269.741368    20.338973   18.281009
# k99_1006998_1       137.541238   16.956252   105.403932   17.336581
# k99_1007311_1        52.131438  228.362410    26.485740  196.476485
# k99_1007631_1         9.038559   46.606115  1128.870371   15.314261
# k99_1007659_2        62.831065  302.385864    24.794732    7.176967
# k99_100772_1         48.211895  373.702282    23.264329  121.162355
# k99_1007949_1        49.285397  178.029218    31.586833   68.288730
# k99_1008105_1        23.934693   35.413779    30.884223  153.488932
# k99_1008105_2        19.853697   49.171634   345.129520  155.586749
# k99_1008105_3        22.624244   51.710949    28.625361  164.788802
# k99_1008180_1        26.735054  235.855610   111.598174   28.519930
# k99_1008218_1        57.914429  171.654608    36.243821   40.396772
# k99_1008435_3        51.387261  140.366705    61.901285   91.628428
# k99_1008548_2       122.452632  195.462071    47.728523  131.932277
# k99_1008597_2        55.105001  606.904975     7.139729  193.304802
# k99_1008705_2       185.325284  127.312305    71.008522   72.224352
# k99_1008991_1        45.283593   43.438743    24.628750    7.154000
# ...                        ...         ...          ...         ...
# k99_986881_2         60.565922   94.545120    28.180323  121.394564
# k99_988185_3         65.221674   50.037052    25.940555  139.556174
# k99_989559_1         64.941353   33.978277    12.991661   62.919910
# k99_989607_1         39.977930  163.316391    53.464826   84.602661
# k99_989714_5        181.006556   99.057888    58.995529   82.048609
# k99_989874_5         54.006182   28.161478    48.214084   59.162636
# k99_990427_1        149.829822  327.653439    62.410996   14.494765
# k99_990682_2         30.446200  121.973523   411.428478  163.663505
# k99_991061_1         38.456098  146.162365    15.851840   80.470856
# k99_991419_1        187.718389  354.255053    84.073836   11.267959
# k99_991741_1         96.863843    6.997331    12.687838   28.004871
# k99_991826_1         28.637388  105.409735   400.144006  258.115744
# k99_991826_3         23.240362   32.949575   130.358814   59.896302
# k99_99188_2          42.533944  101.070831    38.945893  258.366007
# k99_992336_2        164.542825   30.371297   525.937837   35.865205
# k99_992839_2         52.515811  236.883788   130.909592  123.933795
# k99_99300_10         62.307465  128.704373    53.509529  110.656657
# k99_993197_4         18.588861   13.478309   615.029349  337.343961
# k99_993759_8         97.324389    7.107926    53.071577    2.960770
# k99_9941_1           77.250724  155.156430    27.444070  118.640369
# k99_99441_1           6.678438   14.575007    50.024170    7.771759
# k99_99524_2          96.598168   66.783737    91.903437  114.752923
# k99_995394_1        116.885412   39.239192    66.832456   99.410804
# k99_995896_4        193.934256   26.622678    38.868802   65.478220
# k99_996093_4        104.828364   38.132320    75.026077   37.963569
# k99_996122_1         78.468709   20.547345    17.674589   11.628088
# k99_997245_1         37.827363    4.753547    11.551204    4.308847
# k99_997813_2        108.503469   67.252983   144.743062  102.948664
# k99_997813_3        117.228353   64.383382   386.126155   95.920584
# k99_99970_1          27.638691  104.012192     9.661892   94.329046
#
#                            L26
# datarest$ProteinID
# k99_1000928_1        60.128184
# k99_1001938_3        35.278634
# k99_1001990_2       143.500305
# k99_1002150_3        48.171145
# k99_1002370_6        79.388883
# k99_1002967_3        68.751905
# k99_1003965_10      104.356005
# k99_1004041_1        40.778811
# k99_1004623_1        39.151955
# k99_1005212_10       85.003125
# k99_1005337_1        87.443748
# k99_1005475_1        53.925726
# k99_1005733_1       141.809785
# k99_1006916_3        82.846367
# k99_1006998_1        22.917993
# k99_1007311_1        78.682065
# k99_1007631_1         9.883403
# k99_1007659_2       193.394550
# k99_100772_1        335.377411
# k99_1007949_1        83.179259
# k99_1008105_1        30.721960
# k99_1008105_2        30.769563
# k99_1008105_3        13.913015
# k99_1008180_1        45.642919
# k99_1008218_1       119.941563
# k99_1008435_3        44.829909
# k99_1008548_2        58.422157
# k99_1008597_2        42.680944
# k99_1008705_2        65.413707
# k99_1008991_1       285.272588
# ...                        ...
# k99_986881_2         60.364492
# k99_988185_3         16.241541
# k99_989559_1         11.676106
# k99_989607_1         16.568652
# k99_989714_5        144.450007
# k99_989874_5         15.641727
# k99_990427_1         90.445981
# k99_990682_2         56.555794
# k99_991061_1         57.616524
# k99_991419_1         11.200960
# k99_991741_1         72.402798
# k99_991826_1         49.954926
# k99_991826_3         21.846505
# k99_99188_2          24.085724
# k99_992336_2         66.438763
# k99_992839_2        102.075627
# k99_99300_10         47.255105
# k99_993197_4         16.132682
# k99_993759_8          6.403968
# k99_9941_1           34.738022
# k99_99441_1           8.543831
# k99_99524_2          16.189056
# k99_995394_1        122.105325
# k99_995896_4        138.665934
# k99_996093_4         37.513253
# k99_996122_1         13.298897
# k99_997245_1         29.672485
# k99_997813_2         78.854286
# k99_997813_3         72.614930
# k99_99970_1          40.535102
#
# [10133 rows x 40 columns]

# %%
df.to_csv('./2Search/CSVs/NormalizedCommonReps_nohuman.txt', sep = '\t')

# %% [markdown]
# ### Create Biom Files

# %%
#2 Search pDB Approach - no human
#Convert tab-separated file to biom file
# !biom convert -i ./2Search/CSVs/NormalizedCommonReps_nohuman.txt \
-o ./2Search/NormalizedCommonReps2_nohuman.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %%
#2 Search pDB Approach
#Convert tab-separated file to biom file
# !biom convert -i ./2Search/CSVs/NormalizedCommonReps.txt \
-o ./2Search/NormalizedCommonReps2.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %%
#Metabolomics
#Convert tab-separated file to biom file
# !biom convert -i ../Metabolomics/Feature_table.txt \
-o ./Metabolomics.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %%
#16S
#Convert tab-separated file to biom file
# !biom convert -i ../Genomics/16S/reference-hit_idswap2_blankremove.txt \
-o ./16S.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %%
#Serum
# !biom convert -i ../Serum/CSVs/NormalizedCommonReps_ids.txt \
-o ./Serum_Common.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %%
#MG
# !biom convert -i ../Genomics/Shotgun/Salmon_CPMs_0s.txt \
-o ./Salmon_CPMs.biom \
-m ../UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %% [markdown]
# ### Import all as Qiime2 artifacts

# %%
# !qiime tools import \
  --input-path ./Metabolomics.biom \
  --type 'FeatureTable[Frequency]' \
  --output-path Metabolomics_biom.qza

# %%
# !qiime tools import \
  --input-path ./2Search/NormalizedCommonReps2.biom\
  --type 'FeatureTable[Frequency]' \
  --output-path 2search_common_biom.qza

# %%
# !qiime tools import \
  --input-path ./16S.biom\
  --type 'FeatureTable[Frequency]' \
  --output-path 16S_biom.qza

# %%
# !qiime tools import \
  --input-path ./Salmon_CPMs.biom\
  --type 'FeatureTable[Frequency]' \
  --output-path ./Salmon_CPMs_biom.qza

# %%
# !qiime tools import \
  --input-path ./Serum_Common.biom\
  --type 'FeatureTable[Frequency]' \
  --output-path ./Serum_Common_biom.qza

# %%
# !qiime tools import \
  --input-path ./2Search/NormalizedCommonReps2_nohuman.biom\
  --type 'FeatureTable[Frequency]' \
  --output-path ./pDB_Common_nohuman_biom.qza

# %%
#Metagenomics using UniFrac. Based on centrifuge counts.
# !qiime tools import \
  --input-path ./Genomics/Shotgun/all.filt.biom \
  --type 'FeatureTable[Frequency]' \
  --output-path MG_all_biom.qza

# %% [markdown]
# ### Feature table summarize

# %%
# !qiime feature-table summarize \
  --i-table ./pDB_Common_nohuman_biom.qza \
  --o-visualization ./pDB_Common_nohuman_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# Saved Visualization to: ./pDB_Common_nohuman_biom.qzv

# %%
# !qiime feature-table summarize \
  --i-table Metabolomics_biom.qza \
  --o-visualization Metabolomics_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# Saved Visualization to: Metabolomics_biom.qzv

# %%
# !qiime feature-table summarize \
  --i-table 2search_common_biom.qza \
  --o-visualization 2search_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# Saved Visualization to: 2search_biom.qzv

# %%
# !qiime feature-table summarize \
  --i-table 16S_biom.qza \
  --o-visualization 16S_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# Saved Visualization to: 16S_biom.qzv

# %%
# !qiime feature-table summarize \
  --i-table ./Serum_Common_biom.qza \
  --o-visualization ./Serum_Common_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# Saved Visualization to: ./Serum_Common_biom.qzv

# %%
# !qiime feature-table summarize \
  --i-table ./Salmon_CPMs_biom.qza \
  --o-visualization Salmon_CPMs_biom.qzv \
  --m-sample-metadata-file ../UC_MP_Emperor_Map.txt
# Out:
# ^C
#
# Aborted!

# %%
qiime feature-table summarize \
  --i-table ./Serum_biom.qza \
  --o-visualization Serum_biom.qzv \
  --m-sample-metadata-file ../../UC_MP_Emperor_Map.txt

# %% [markdown]
# ### Qiime 1 PCoAs

# %%
# !validate_mapping_file.py -o vmf-map/ -m ../UC_MP_Emperor_Map_10052018.txt
# Out:
# Errors and/or warnings detected in mapping file.  Please check the log and html file for details.

# %%
from IPython.display import FileLinks, FileLink
FileLinks('vmf-map/')
# Out:
# vmf-map/
#   UC_MP_Emperor_Map_10052018.html
#   overlib.js
#   UC_MP_Emperor_Map_10052018_corrected.txt
#   UC_MP_Emperor_Map_10052018.log

# %%
# !beta_diversity_through_plots.py -i ./Metabolomics.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_Metabolomics -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -4.15747501546 and the largest is 2.36480772077e+16.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0035096125299 and the largest is 0.948397941533.
#   RuntimeWarning

# %%
# !beta_diversity_through_plots.py -i ./2Search/NormalizedCommonReps2.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_2search -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:

# %%
# !beta_diversity_through_plots.py -i ./16S.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_16S -p ../smallDB_correct/PCoA_Plots/paramaters2_16S.txt -t ../Genomics/16S/insertion_tree.relabelled.tre
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0305262601337 and the largest is 1.70812132461.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0669606719016 and the largest is 3.17652373099.
#   RuntimeWarning

# %%
# !beta_diversity_through_plots.py -i ./Salmon_CPMs.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_MG -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:

# %%
# !beta_diversity_through_plots.py -i ./Serum_Common.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_Serum -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.42588933238e-07 and the largest is 295304255.711.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00387462944193 and the largest is 0.497876640547.
#   RuntimeWarning

# %%
# !beta_diversity_through_plots.py -i ./2Search/NormalizedCommonReps2_nohuman.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_2search_nohuman -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.66231375683e-06 and the largest is 2297967245.68.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:

# %%
# !beta_diversity_through_plots.py -i ../Serum/UC_Serum_CommonReps_nored_hdf5.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_Serum_nored -p ../smallDB_correct/PCoA_Plots/paramaters2.txt
# Out:
# Traceback (most recent call last):
#   File "/Users/rhmills/miniconda3/envs/qiime1/bin/beta_diversity_through_plots.py", line 4, in <module>
#     __import__('pkg_resources').run_script('qiime==1.9.1', 'beta_diversity_through_plots.py')
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/pkg_resources/__init__.py", line 750, in run_script
#     self.require(requires)[0].run_script(script_name, ns)
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/pkg_resources/__init__.py", line 1527, in run_script
#     exec(code, namespace, namespace)
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/qiime-1.9.1-py2.7.egg-info/scripts/beta_diversity_through_plots.py", line 153, in <module>
#     main()
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/qiime-1.9.1-py2.7.egg-info/scripts/beta_diversity_through_plots.py", line 127, in main
#     create_dir(output_dir, fail_on_exist=not opts.force)
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/util/_misc.py", line 225, in create_dir
#     return ror(error_code_lookup['DIR_EXISTS'])
#   File "/Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/util/_misc.py", line 334, in _handle_error_codes
#     raise OSError(error_strings[error_code])
# OSError: Directory already exists: ./Qiime/PCoA_Serum_nored

# %%
# !beta_diversity_through_plots.py -i ../Genomics/Shotgun/all.filt.biom -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -o ./Qiime/PCoA_MG_allUniq -p ../smallDB_correct/PCoA_Plots/paramaters2_16S.txt -t ../Genomics/Shotgun/tree.nwk
# Out:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:456: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00722017075537 and the largest is 1.82941390622e+13.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/cogent/maths/distance_transform.py:188: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   if rank(datamtx) != 2:
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0377227709131 and the largest is 2.30405445323.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00104850689555 and the largest is 1.30424230145.
#   RuntimeWarning
# /Users/rhmills/miniconda3/envs/qiime1/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.139427821991 and the largest is 8.31575816029.
#   RuntimeWarning

# %% [markdown]
# ### Qiime 1 Beta-Diversity Statistics Adonis & PERMANOVA

# %%
# !pwd
# Out:
# /Users/rhmills/Documents/Thesis Work/UC_Severity/pDB_Proteomics

# %%
#Data types which require PERMANOVA categorical significance.
Perma = ['sex','race','historic_extent','ASA_exposure', 'current_5ASA', 'steroid_exposure', 'current_steroids', 'IM_exposure', 'IM_type', 'biologic_exposure',
        'biologic_exposure_type','current_biologic','current_biologic_type','Experiment','TMT_Label']
Adonis = ['CRP','Calprotectin', 'partial_mayo','age','age_diagnosis','disease_duration','height','stool_frequency','rectal_bleeding','PGA','mayo_endoscopic_score','UCEIS_endoscopic_score','COLLECTION_TIMESTAMP','Endoscopy_date']

# %%
#Iterative Permanovas on MG UniFrac
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_MG_allUniq/unweighted_unifrac_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/MG_UniFrac/$i

# %%
#Iterative Adonis on MG UniFrac
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_MG_allUniq/unweighted_unifrac_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/MG_UniFrac/$i -n 999

# %%
#Iterative Permanovas on 16S
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_16S/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/16S_bray/$i

# %%
#Iterative Permanovas on 16S - all samples
for i in Perma:
        # !compare_categories.py --method permanova -i ../Genomics/16S/core-metrics-results_idswap2_newmetadata_allsamples/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/16S_bray/$i

# %%
#Iterative Adonis on 16S
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_16S/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/16S_bray/$i -n 999

# %%
#Iterative Permanovas on pDB
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_2search/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/pDB_MP/$i

# %%
#Iterative Adonis on pDB
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_2search/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/pDB_MP/$i -n 999

# %%
#Iterative Permanovas on pDB NOHUMAN
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_2search_nohuman/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/pDB_MP_nohuman/$i

# %%
#Iterative Adonis on pDB NOHUMAN
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_2search_nohuman/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/pDB_MP_nohuman/$i -n 999

# %%
#Iterative Permanovas on Metabolomics
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_Metabolomics/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/Metabolomics/$i

# %%
#Iterative Adonis on Metabolomics
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_Metabolomics/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/Metabolomics/$i -n 999

# %%
#Iterative Permanovas on Metagenome
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_MG/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/MG/$i

# %%
#Iterative Adonis on Metagenome
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_MG/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/MG/$i -n 999

# %%
#Iterative Permanovas on Serum
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_Serum/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/Serum/$i

# %%
#Iterative Adonis on Serum
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_Serum/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/Serum/$i -n 999

# %%
#Iterative Permanovas on Serum NORED
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_Serum_nored/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/Serum_nored/$i

# %%
#Iterative Adonis on Serum NORED
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_Serum_nored/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/Serum_nored/$i -n 999

# %%
#Iterative Permanovas on 16S
for i in Perma:
        # !compare_categories.py --method permanova -i ./Qiime/PCoA_16S/unweighted_unifrac_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Permanova/16S/$i

# %%
#Iterative Adonis on 16S
for i in Adonis:
        # !compare_categories.py --method adonis -i ./Qiime/PCoA_16S/unweighted_unifrac_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c $i -o ./Qiime/Adonis/16S/$i -n 999

# %%
# !compare_categories.py --method permanova -i ./Qiime/PCoA_2search/bray_curtis_dm.txt -m ./vmf-map/UC_MP_Emperor_Map_10052018_corrected.txt -c IM_type -o ./Qiime/Permanova/pDB_MP/IM_type

# %% [markdown]
# ### Core metrics - Qiime2

# %%
#2Searh pDB using the no-human proteins
# !qiime diversity core-metrics \
  --i-table pDB_Common_nohuman_biom.qza \
    --p-sampling-depth 539826 \
--m-metadata-file ../UC_MP_Emperor_Map.txt \
--output-dir core-metrics-results_pDB_noHuman
# Out:
# Saved FeatureTable[Frequency] to: core-metrics-results_pDB_noHuman/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_pDB_noHuman/observed_otus_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_pDB_noHuman/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_pDB_noHuman/evenness_vector.qza
# Saved DistanceMatrix to: core-metrics-results_pDB_noHuman/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: core-metrics-results_pDB_noHuman/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: core-metrics-results_pDB_noHuman/jaccard_pcoa_results.qza
# Saved PCoAResults to: core-metrics-results_pDB_noHuman/bray_curtis_pcoa_results.qza
# Saved Visualization to: core-metrics-results_pDB_noHuman/jaccard_emperor.qzv
# Saved Visualization to: core-metrics-results_pDB_noHuman/bray_curtis_emperor.qzv

# %%
#Huge experimental (TMT experiment) variability in this approach.

# !qiime diversity core-metrics \
  --i-table 2search_common_biom.qza \
    --p-sampling-depth 694193 \
--m-metadata-file ../UC_MP_Emperor_Map.txt \
--output-dir core-metrics-results_2search
# Out:
# Saved FeatureTable[Frequency] to: core-metrics-results_2search/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_2search/observed_otus_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_2search/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_2search/evenness_vector.qza
# Saved DistanceMatrix to: core-metrics-results_2search/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: core-metrics-results_2search/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: core-metrics-results_2search/jaccard_pcoa_results.qza
# Saved PCoAResults to: core-metrics-results_2search/bray_curtis_pcoa_results.qza
# Saved Visualization to: core-metrics-results_2search/jaccard_emperor.qzv
# Saved Visualization to: core-metrics-results_2search/bray_curtis_emperor.qzv

# %%
#Huge experimental (TMT experiment) variability in this approach.

# !qiime diversity core-metrics \
  --i-table IGC_biom.qza \
    --p-sampling-depth 1813092 \
--m-metadata-file ../UC_MP_Emperor_Map.txt \
--output-dir core-metrics-results_IGC
# Out:
# Saved FeatureTable[Frequency] to: core-metrics-results_IGC/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_IGC/observed_otus_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_IGC/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_IGC/evenness_vector.qza
# Saved DistanceMatrix to: core-metrics-results_IGC/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: core-metrics-results_IGC/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: core-metrics-results_IGC/jaccard_pcoa_results.qza
# Saved PCoAResults to: core-metrics-results_IGC/bray_curtis_pcoa_results.qza
# Saved Visualization to: core-metrics-results_IGC/jaccard_emperor.qzv
# Saved Visualization to: core-metrics-results_IGC/bray_curtis_emperor.qzv

# %%
#Metabolomics

# !qiime diversity core-metrics \
  --i-table Metabolomics_biom.qza \
    --p-sampling-depth 184074904 \
--m-metadata-file ../UC_MP_Emperor_Map.txt \
--output-dir core-metrics-results_Metabolomics
# Out:
# Saved FeatureTable[Frequency] to: core-metrics-results_Metabolomics/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_Metabolomics/observed_otus_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_Metabolomics/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: core-metrics-results_Metabolomics/evenness_vector.qza
# Saved DistanceMatrix to: core-metrics-results_Metabolomics/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: core-metrics-results_Metabolomics/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: core-metrics-results_Metabolomics/jaccard_pcoa_results.qza
# Saved PCoAResults to: core-metrics-results_Metabolomics/bray_curtis_pcoa_results.qza
# Saved Visualization to: core-metrics-results_Metabolomics/jaccard_emperor.qzv
# Saved Visualization to: core-metrics-results_Metabolomics/bray_curtis_emperor.qzv

# %%
#Shannon diversity metabolome

# !qiime diversity alpha \
  --i-table Metabolomics_biom.qza \
  --p-metric shannon \
  --o-alpha-diversity Metabolome_shannon.qza
# Out:
# Saved SampleData[AlphaDiversity] to: Metabolome_shannon.qza

# %% [markdown]
# ### Random Forest Classifier - Qiime2

# %%
#Code for determining features most related to the pielou evenness - supplemental figure

# !qiime sample-classifier regress-samples \
--i-table ./16S_biom.qza \
--m-metadata-file ../UC_MP_Emperor_Map.txt \
--m-metadata-column pielou_e \
--p-optimize-feature-selection \
--p-parameter-tuning \
--p-estimator RandomForestRegressor \
--o-visualization \
../Random_Forests/pieloue_rforest_16S.qzv
# Out:
# Saved Visualization to: ../Random_Forests/pieloue_rforest_16S.qzv

# %%
#Create combined table with all data
Mb = pd.read_csv('./Metabolomics/Feature_table.txt', sep = '\t', index_col = '#OTUID')
Mp = pd.read_csv('./pDB_Proteomics/2Search/CSVs/NormalizedCommonReps.txt', sep = '\t', index_col = 'datarest$ProteinID')
Ser = pd.read_csv('./Serum/CSVs/NormalizedCommonReps_ids.txt', sep = '\t', index_col = 'datarest$ProteinID')
MG = pd.read_csv('./Genomics/Shotgun/Salmon_CPMs_0s.txt', sep = '\t', index_col = '#OTU')
Amp = pd.read_csv('./Genomics/16S/reference-hit_idswap2_noblanks.txt', sep = '\t', index_col = '#OTU ID')

#Overlapping IDS are a problem, so append the metaproteome ids with _MP to signify metaproteome.
Mp.index = Mp.index + '_MP'

#Concatenate data
Objs = [Mb, Mp, Ser, MG, Amp]
alldf = pd.concat(Objs)

alldf.index.rename('Features', inplace = True)

#Save the new feature table
#alldf.to_csv('./allfeaturesconcat.txt', sep = '\t')

# %%
#Create biom file
# !biom convert -i ./allfeaturesconcat.txt \
-o ./Allfeaturesconcat.biom \
-m ./UC_MP_Emperor_Map_1.txt \
--table-type="OTU table" --to-hdf5

# %% [markdown]
# <i> Performed random forest analyses on supercomputer using the Allfeaturesconcat.biom file </i>

# %% [markdown]
# ### 16S analysis - Qiime2

# %%
# Initializes the notebook with inline display
# %matplotlib inline

from os import mkdir
import os
import copy
from os.path import abspath, join as pjoin, exists
from shutil import copy2, move
from time import strftime, strptime
from numpy import nan, isnan, arange
from pandas import read_csv, Series, DataFrame
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import FileLinks, FileLink

# %%
# !validate_mapping_file.py -o vmf-map/ -m ./11549_prep_4716_qiime_20180508-114955.txt

# %%
# !biom convert -i ./reference-hit_idswap2.txt -o ./reference-hit_idswap2.biom --table-type="OTU table" --to-hdf5

# %% [markdown]
# #### Import all files as Qiime2 artifacts

# %%
# !qiime tools import \
  --input-path reference-hit_idswap2.biom \
  --type 'FeatureTable[Frequency]' \
  --output-path biom_id2.qza

# %%
# !qiime feature-table summarize \
  --i-table biom_id2.qza \
  --o-visualization biom_id2.qzv \
  --m-sample-metadata-file ./UC_Severity_1_MF_Idswap6.21.18.txt

# %%
## rep-seqs 
# !qiime tools import \
  --input-path reference-hit.seqs.fa \
  --output-path sequences.qza \
  --type 'FeatureData[Sequence]'

# %%
# !qiime alignment mafft \
  --i-sequences sequences.qza \
  --o-alignment aligned-rep-seqs.qza

# %%
# !qiime alignment mask \
  --i-alignment aligned-rep-seqs.qza \
  --o-masked-alignment masked-aligned-rep-seqs.qza

# %%
# !qiime phylogeny fasttree \
  --i-alignment masked-aligned-rep-seqs.qza \
  --o-tree unrooted-tree.qza

# %%
# !qiime phylogeny midpoint-root \
  --i-tree unrooted-tree.qza \
  --o-rooted-tree rooted-tree.qza

# %% [markdown]
# #### Core Diversity Analysis

# %%
# !qiime diversity core-metrics-phylogenetic \
  --i-phylogeny rooted-tree.qza \
  --i-table biom_id2.qza \
  --p-sampling-depth 4166 \
  --m-metadata-file UC_Severity_1_MF_Idswap6.21.18.txt \
  --output-dir core-metrics-results_idswap2_newmetadata_allsamples

# %% [markdown]
# #### Alpha diversity analyses

# %%
# !qiime diversity alpha-group-significance \
  --i-alpha-diversity core-metrics-results_idswap2/faith_pd_vector.qza \
  --m-metadata-file UC_Severity_1_MF_Idswap6.21.18.txt \
  --o-visualization core-metrics-results_idswap2_newmetadata/faith-pd-group-significance.qzv

# %%
# !qiime diversity alpha-group-significance \
  --i-alpha-diversity core-metrics-results_idswap2/evenness_vector.qza \
  --m-metadata-file UC_Severity_1_MF_Idswap6.21.18.txt \
  --o-visualization core-metrics-results_idswap2_newmetadata/evenness-group-significance.qzv

# %% [markdown]
# #### Taxanomic analysis

# %%
# !qiime feature-classifier classify-sklearn \
  --i-classifier gg-13-8-99-515-806-nb-classifier.qza \
  --i-reads sequences.qza \
  --o-classification taxonomy.qza

# %%
# !qiime metadata tabulate \
  --m-input-file taxonomy.qza \
  --o-visualization taxonomy.qzv

# %%
# !qiime taxa barplot \
  --i-table biom_id2.qza \
  --i-taxonomy taxonomy.qza \
  --m-metadata-file UC_Severity_1_MF_Idswap6.21.18.txt \
  --o-visualization taxa-bar-plots_idswap2.qzv
